# %%
# My first Python code in Jupyter
print("Hello from my organized data folder!")
# Out:
# Hello from my organized data folder!

# %%
# Let's create a variable
my_message = "This variable will remember its value"
print(my_message)
# Out:
# This variable will remember its value

# %%
print(my_message)
# Out:
# This variable will remember its value

# %% [markdown]
# # My Experiment Notes
#
# ## Purpose
# Testing the matter manifestation apparatus
#
# ## Parameters Used
# - Current: 18.5 mA
# - Magnet configuration: 6-pole
# - Date: March 9, 2026

# %% [markdown]
# # My Matter Manifestation Experiment
# **Date:** March 9, 2026
# **Current:** 18.5 mA
# **Result:** Visible pattern formed
